# %%
#list to tuple conversion
lst = [10, 20, 30]
tup = tuple(lst)
print(tup)
# Out:
# (10, 20, 30)

# %%
#list tu set conversion
lst = [10, 20, 20, 30]
set = set(lst)
print(set)
# Out:
# {10, 20, 30}

# %%
#tuple to list conversion
tup = (5, 10, 15)
lst = list(tup)
print(lst)
# Out:
# [5, 10, 15]

# %%
#tuple to set conversion
tuple = (5, 10, 10, 15)
set = set(tuple)
print(set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #tuple to set conversion
#       2 tuple = (5, 10, 10, 15)
# ----> 3 set = set(tuple)
#       4 print(set)
#       5
#       6
#
# TypeError: 'set' object is not callable

# %%
#set to list conversion
set = {1, 2, 3}
lst = list(set)
print(lst)
# Out:
# [1, 2, 3]

# %%
#set to tuple 
set = {1, 2, 3}
tup = tuple(set)
print(tup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 #set to tuple
#       2 set = {1, 2, 3}
# ----> 3 tup = tuple(set)
#       4 print(tup)
#
# TypeError: 'tuple' object is not callable

# %%
#diction key list
dict = {"A": 1, "B": 2}
keys = list(dict.keys())
print(keys)
# Out:
# ['A', 'B']

# %%
#index Accessing
lag = "Python"
print(lag[0])
# Out:
# P

# %%
#for any element
lag = "Python"
print(lag[4])
# Out:
# o

# %%
#nagative indexing
lag = "Python"
print(lag[-4])
# Out:
# t

# %%
#concatination
palt = "Jupyter"
print(palt[0:3])
# Out:
# Jup
