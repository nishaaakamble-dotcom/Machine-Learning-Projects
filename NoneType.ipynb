# %%
x = None

print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>

# %%
name = None

print(name)
# Out:
# None

# %%
x = None

if x is None:
    print("x has no value")
# Out:
# x has no value

# %%
def greet():
    print("Hello")

result = greet()

print(result)
# Out:
# Hello
# None
