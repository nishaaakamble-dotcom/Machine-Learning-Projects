# %%
student = {
    "name": "Nisha",
    "age": 20,
    "city": "Pune"
}

print(student)
# Out:
# {'name': 'Nisha', 'age': 20, 'city': 'Pune'}

# %%
student = {"name": "Nisha", "age": 20}

print(student.keys())
# Out:
# dict_keys(['name', 'age'])

# %%
student = {"name": "Nisha", "age": 20}

print(student.values())
# Out:
# dict_values(['Nisha', 20])

# %%
student = {"name": "Nisha", "age": 20}

print(student.items())
# Out:
# dict_items([('name', 'Nisha'), ('age', 20)])

# %%
student = {"name": "Nisha", "age": 20}

print(student.get("name"))
# Out:
# Nisha

# %%
student = {"name": "Nisha", "age": 20}

student.update({"city": "Pune"})
print(student)
# Out:
# {'name': 'Nisha', 'age': 20, 'city': 'Pune'}

# %%
student = {"name": "Nisha", "age": 20}

new_dict = student.copy()
print(new_dict)
# Out:
# {'name': 'Nisha', 'age': 20}
